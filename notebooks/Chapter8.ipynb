# %%
# %matplotlib notebook
import cmath
from functools import reduce

import matplotlib.pyplot as plt
import numpy as np

import sys
sys.path.append('..')

from indra.common import Circle, Line
from indra.mobius import MobiusTransformation as Mobius
from indra.plotting.tiles import plot_tiles
from indra.plotting.limit import plot_limit_set
from indra.recipes import parabolic_commutator

# %%
gens = parabolic_commutator(2, 2)

# %%
plot_limit_set(gens)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
gens2 = parabolic_commutator(2*np.sqrt(2), 2*np.sqrt(2), use_negative=False)
gens3 = parabolic_commutator(2*np.sqrt(2), 2*np.sqrt(2), use_negative=True)

# %%
np.isclose(gens2[0](gens2[1]).M.trace(), gens3[0](gens3[1]).M.trace())
# Out:
# True

# %%
plot_limit_set(gens2)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
gens = parabolic_commutator(2.2, 2.2)
plot_limit_set(gens, linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="936">

# %%
gens = parabolic_commutator(1.91 + 0.05j, 1.91 + 0.05j)
plot_limit_set(gens, eps=1e-2, linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="966">

# %%
gens = parabolic_commutator(2, 3)
plot_limit_set(gens, linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="944">

# %%
gens = parabolic_commutator(3, 2)
plot_limit_set(gens, linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
gens = parabolic_commutator(1.887 + 0.05j, 2)
plot_limit_set(gens, eps=1e-3, linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="955">

# %%
# testing out plotting ranges
gens = parabolic_commutator(1.91 + 0.05j, 1.91 + 0.05j)
plot_limit_set(gens, beg_prefix='abbbbb', end_prefix='abbbbb', linewidth=0.5)
# Out:
# <img src="data:image/png;base64,..." width="640">
